# %% [markdown]
# # 预测自己图像及可视化

# %%
import os
os.chdir('mmdetection')

# %%
# !python demo/image_demo.py demo/balloon.png work_dirs/pre_config/pre_config.py --weights work_dirs/bestepoch_100.pth
# Out:
# Loads checkpoint by local backend from path: work_dirs/bestepoch_100.pth
# 06/12 00:08:45 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# 06/12 00:08:45 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# Inference ----------------------------------------
# results have been saved at outputs
# e:\anaconda\envs\pytorch\lib\site-packages\torch\functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:2895.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
from PIL import Image
Image.open('outputs/vis/balloon.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=641x599>

# %% [markdown]
# # 图像可视化

# %%
import os
os.chdir('mmyolo')

# %%
# !python demo/featmap_vis_demo.py \
      ../mmdetection/demo/balloon_resize.png \
      ../mmdetection/work_dirs/pre_config/pre_config.py \
      ../mmdetection/work_dirs/bestepoch_100.pth  \
      --target-layers backbone  \
      --channel-reduction squeeze_mean
# Out:
# Loads checkpoint by local backend from path: ../mmdetection/work_dirs/bestepoch_100.pth
# 06/12 00:09:21 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# [                                                  ] 0/1, elapsed: 0s, ETA:
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 1/1, 0.2 task/s, elapsed: 6s, ETA:     0sAll done!
# Results have been saved at f:\GitHub\MMDetection_Tutorials\mmdet-0829\mmyolo\output
# e:\anaconda\envs\pytorch\lib\site-packages\torch\functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:2895.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# e:\anaconda\envs\pytorch\lib\site-packages\mmengine\visualization\visualizer.py:757: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#   warnings.warn(
# ...

# %%
from PIL import Image
Image.open('output/balloon.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1282x1198>
