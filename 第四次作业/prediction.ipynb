# %% [markdown]
# # 训练、测试、预测

# %%
import os
os.chdir('mmsegmentation')

# %%
# !python tools/train.py data/psp-config.py

# %%
# !python tools/test.py data/psp-config.py work_dirs/best.pth

# %%
# !python demo/image_demo.py \
        data/test2.png \
        data/psp-config.py \
        work_dirs/iter_300.pth \
        --out-file output/test2.jpg \
        --device cuda:0 \
        --opacity 0.7
# Out:
# Loads checkpoint by local backend from path: work_dirs/iter_300.pth
# 06/18 11:53:32 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# f:\github\openmmlab_mmsegmentation\openmmlab_mmsegmentation-main\mmsegmentation\mmseg\models\builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# f:\github\openmmlab_mmsegmentation\openmmlab_mmsegmentation-main\mmsegmentation\mmseg\models\losses\cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(

# %%
from PIL import Image
Image.open('output/test.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=748x573>

# %%
from PIL import Image
Image.open('output/test2.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=986x676>
